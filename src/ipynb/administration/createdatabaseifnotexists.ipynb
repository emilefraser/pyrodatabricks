# %% [markdown]
# |Action Taken|Description|
# |--|--|
# |Create Database If Not Exists - datalakehouse_silver|Tables in the silver layer of the lake house are stored here. |
# |Create Database If Not Exists - datalakehouse_platinum|Tables in the platinum layer of the lake house are stored here. E.g. Dimensions, Facts|

# %%
# %sql
CREATE DATABASE IF NOT EXISTS datalakehouse_silver
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>

# %%
# %sql
CREATE DATABASE IF NOT EXISTS datalakehouse_platinum
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
